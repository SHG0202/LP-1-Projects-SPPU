# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2

# !nvcc --version

# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git

# %load_ext nvcc_plugin
# Out:
# Removing libxfont2:amd64 (1:2.0.3-1) ...
# Removing libfontenc1:amd64 (1:1.1.3-1) ...
# Removing libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Removing libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Removing libjansson4:amd64 (2.11-1) ...
# Removing libnpp-dev-11-0 (11.1.0.245-1) ...
# Removing libnpp-11-0 (11.1.0.245-1) ...
# Removing libnvjpeg-dev-11-0 (11.1.1.245-1) ...
# Removing libnvjpeg-11-0 (11.1.1.245-1) ...
# Removing libnvjpeg-dev-11-1 (11.3.0.105-1) ...
# Removing libnvjpeg-11-1 (11.3.0.105-1) ...
# Removing libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Removing libxi-dev:amd64 (2:1.7.9-1) ...
# Removing xserver-common (2:1.19.6-1ubuntu4.9) ...
# Removing x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Removing libxkbfile1:amd64 (1:1.0.9-2) ...
# Removing libxmu-dev:amd64 (2:1.1.2-2) ...
# Removing libxmu-headers (2:1.1.2-2) ...
# Removing libxnvctrl0:amd64 (495.29.05-0ubuntu1) ...
# Removing openjdk-11-jre:amd64 (11.0.11+9-0ubuntu2~18.04) ...
# Removing libxtst6:amd64 (2:1.2.3-1) ...
# Removing nsight-compute-2020.2.1 (2020.2.1.8-1) ...
# Removing nsight-compute-2021.3.1 (2021.3.1.4-1) ...
# Removing nsight-systems-2020.3.2 (2020.3.2.6-87e152c) ...
# Removing nsight-systems-2020.3.4 (2020.3.4.32-52657a0) ...
# update-alternatives: removing manually selected alternative - switching nsys to auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2021.3.3/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: removing manually selected alternative - switching nsight-sys to auto mode
# update-alternatives: removing manually selected alternative - switching nsys-ui to auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2021.3.3/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Removing nsight-systems-2021.3.3 (2021.3.3.2-b99c4d6) ...
# dpkg: warning: while removing nsight-systems-2021.3.3, directory '/usr/local/bin' not empty so not removed
# dpkg: warning: while removing nsight-systems-2021.3.3, directory '/opt' not empty so not removed
# Removing ocl-icd-opencl-dev:amd64 (2.2.11-1ubuntu1) ...
# Removing opencl-c-headers (2.2~2018.02.21-gb5c3680-1) ...
# Removing python3-xkit (0.5.0ubuntu2) ...
# Removing udev (237-3ubuntu10.52) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.9 kB]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [833 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,452 kB]
# Get:17 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,230 kB]
# Hit:19 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,821 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.6 kB]
# Get:26 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [934 kB]
# Get:27 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Fetched 13.8 MB in 7s (1,863 kB/s)
# Reading package lists... Done
# --2021-12-22 04:55:28--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.39.144
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 [following]
# --2021-12-22 04:55:30--  https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb?qM12YwbH4lbUCEvLZ6pSd1VqukZgnmBHV-mtd1dBIRqWUxltZKDJQsE3exnp3TMTq0lgplP1yuYerLhWzxgyjsAFVoYxg5PnfrinnFKJwRw_zZOeBgoAVKjnyPYZpIwhizpTtuHLQOKZSkrT3fNojFdZfI2aB_inoglUlk0VqNsCRTuuTFbmaLlIoZ0L2wKXyh3sGNVtas4KNWnhvAw [following]
# --2021-12-22 04:55:31--  https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb?qM12YwbH4lbUCEvLZ6pSd1VqukZgnmBHV-mtd1dBIRqWUxltZKDJQsE3exnp3TMTq0lgplP1yuYerLhWzxgyjsAFVoYxg5PnfrinnFKJwRw_zZOeBgoAVKjnyPYZpIwhizpTtuHLQOKZSkrT3fNojFdZfI2aB_inoglUlk0VqNsCRTuuTFbmaLlIoZ0L2wKXyh3sGNVtas4KNWnhvAw
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1267391958 (1.2G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.18G   110MB/s    in 11s
#
# 2021-12-22 04:55:42 (108 MB/s) - ‘cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb’ saved [1267391958/1267391958]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-9-2-local.
# (Reading database ... 111685 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1604-9-2-local (9.2.88-1) ...
# Setting up cuda-repo-ubuntu1604-9-2-local (9.2.88-1) ...
# OK
# Get:1 file:/var/cuda-repo-9-2-local  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [819 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [819 B]
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:5 file:/var/cuda-repo-9-2-local  Packages [18.7 kB]
# Ign:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:12 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:18 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:19 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-9-2' for regex 'cuda-9.2'
# Note, selecting 'libcuda-9.2-1' for regex 'cuda-9.2'
# The following additional packages will be installed:
#   cuda-command-line-tools-9-2 cuda-compiler-9-2 cuda-cublas-9-2
#   cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2 cuda-cufft-9-2
#   cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2 cuda-curand-9-2
#   cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-demo-suite-9-2
#   cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers cuda-drivers-495
#   cuda-gdb-9-2 cuda-gpu-library-advisor-9-2 cuda-libraries-9-2
#   cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-runtime-9-2
#   cuda-samples-9-2 cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2
#   default-jre dkms dmsetup fakeroot fonts-dejavu-core fonts-dejavu-extra
#   freeglut3 freeglut3-dev keyboard-configuration libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfakeroot libfontenc1 libidn11 libip4tc0 libjansson4
#   libnss-systemd libnvidia-cfg1-495 libnvidia-common-495 libnvidia-compute-495
#   libnvidia-decode-495 libnvidia-encode-495 libnvidia-extra-495
#   libnvidia-fbc1-495 libnvidia-gl-495 libpam-systemd libpolkit-agent-1-0
#   libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2 libxi-dev libxkbfile1
#   libxmu-dev libxmu-headers libxnvctrl0 libxtst6 libxxf86dga1
#   networkd-dispatcher nvidia-compute-utils-495 nvidia-dkms-495
#   nvidia-driver-495 nvidia-kernel-common-495 nvidia-kernel-source-495
#   nvidia-modprobe nvidia-prime nvidia-settings nvidia-utils-495
#   openjdk-11-jdk-headless openjdk-11-jre openjdk-11-jre-headless policykit-1
#   policykit-1-gnome python3-xkit screen-resolution-extra systemd systemd-sysv
#   udev x11-utils x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-495
# Suggested packages:
#   python3-apport menu iw | wireless-tools openjdk-11-demo openjdk-11-source
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic systemd-container mesa-utils xfs | xserver
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-495:i386 libnvidia-decode-495:i386
#   libnvidia-encode-495:i386 libnvidia-fbc1-495:i386 libnvidia-gl-495:i386
# The following NEW packages will be installed:
#   cuda-9-2 cuda-command-line-tools-9-2 cuda-compiler-9-2 cuda-cublas-9-2
#   cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2 cuda-cufft-9-2
#   cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2 cuda-curand-9-2
#   cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-demo-suite-9-2
#   cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers cuda-drivers-495
#   cuda-gdb-9-2 cuda-gpu-library-advisor-9-2 cuda-libraries-9-2
#   cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-runtime-9-2
#   cuda-samples-9-2 cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2
#   default-jre dkms dmsetup fakeroot fonts-dejavu-core fonts-dejavu-extra
#   freeglut3 freeglut3-dev keyboard-configuration libargon2-0
#   libatk-wrapper-java libatk-wrapper-java-jni libcap2 libcryptsetup12
#   libdevmapper1.02.1 libfakeroot libfontenc1 libidn11 libip4tc0 libjansson4
#   libnss-systemd libnvidia-cfg1-495 libnvidia-common-495 libnvidia-compute-495
#   libnvidia-decode-495 libnvidia-encode-495 libnvidia-extra-495
#   libnvidia-fbc1-495 libnvidia-gl-495 libpam-systemd libpolkit-agent-1-0
#   libpolkit-backend-1-0 libpolkit-gobject-1-0 libxfont2 libxi-dev libxkbfile1
#   libxmu-dev libxmu-headers libxnvctrl0 libxtst6 libxxf86dga1
#   networkd-dispatcher nvidia-compute-utils-495 nvidia-dkms-495
#   nvidia-driver-495 nvidia-kernel-common-495 nvidia-kernel-source-495
#   nvidia-modprobe nvidia-prime nvidia-settings nvidia-utils-495 openjdk-11-jre
#   policykit-1 policykit-1-gnome python3-xkit screen-resolution-extra systemd
#   systemd-sysv udev x11-utils x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xserver-xorg-core-hwe-18.04
#   xserver-xorg-video-nvidia-495
# The following packages will be upgraded:
#   openjdk-11-jdk-headless openjdk-11-jre-headless
# 2 upgraded, 115 newly installed, 0 to remove and 75 not upgraded.
# Need to get 508 MB/1,654 MB of archives.
# After this operation, 3,311 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-9-2-local  cuda-license-9-2 9.2.88-1 [22.0 kB]
# Get:2 file:/var/cuda-repo-9-2-local  cuda-misc-headers-9-2 9.2.88-1 [640 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-modprobe 495.29.05-0ubuntu1 [19.8 kB]
# Get:4 file:/var/cuda-repo-9-2-local  cuda-nvcc-9-2 9.2.88-1 [15.4 MB]
# Get:5 file:/var/cuda-repo-9-2-local  cuda-cuobjdump-9-2 9.2.88-1 [129 kB]
# Get:6 file:/var/cuda-repo-9-2-local  cuda-nvprune-9-2 9.2.88-1 [36.7 kB]
# Get:7 file:/var/cuda-repo-9-2-local  cuda-compiler-9-2 9.2.88-1 [2,518 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libxnvctrl0 495.29.05-0ubuntu1 [21.4 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  nvidia-settings 495.29.05-0ubuntu1 [923 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers-495 495.29.05-1 [2,612 B]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-drivers 495.29.05-1 [2,500 B]
# Get:12 file:/var/cuda-repo-9-2-local  cuda-nvdisasm-9-2 9.2.88-1 [17.4 MB]
# Get:13 file:/var/cuda-repo-9-2-local  cuda-gdb-9-2 9.2.88-1 [2,765 kB]
# Get:14 file:/var/cuda-repo-9-2-local  cuda-nvprof-9-2 9.2.88-1 [4,737 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 keyboard-configuration all 1.178ubuntu2.9 [369 kB]
# Get:16 file:/var/cuda-repo-9-2-local  cuda-memcheck-9-2 9.2.88-1 [137 kB]
# Get:17 file:/var/cuda-repo-9-2-local  cuda-cudart-9-2 9.2.88-1 [97.8 kB]
# Get:18 file:/var/cuda-repo-9-2-local  cuda-driver-dev-9-2 9.2.88-1 [11.1 kB]
# Get:19 file:/var/cuda-repo-9-2-local  cuda-cudart-dev-9-2 9.2.88-1 [718 kB]
# Get:20 file:/var/cuda-repo-9-2-local  cuda-cupti-9-2 9.2.88-1 [1,537 kB]
# Get:21 file:/var/cuda-repo-9-2-local  cuda-gpu-library-advisor-9-2 9.2.88-1 [1,002 kB]
# Get:22 file:/var/cuda-repo-9-2-local  cuda-nvtx-9-2 9.2.88-1 [24.3 kB]
# Get:23 file:/var/cuda-repo-9-2-local  cuda-command-line-tools-9-2 9.2.88-1 [26.3 kB]
# Get:24 file:/var/cuda-repo-9-2-local  cuda-nsight-9-2 9.2.88-1 [2,580 B]
# Get:25 file:/var/cuda-repo-9-2-local  cuda-nvvp-9-2 9.2.88-1 [2,528 B]
# Get:26 file:/var/cuda-repo-9-2-local  cuda-nvrtc-9-2 9.2.88-1 [5,908 kB]
# Get:27 file:/var/cuda-repo-9-2-local  cuda-nvrtc-dev-9-2 9.2.88-1 [9,318 B]
# Get:28 file:/var/cuda-repo-9-2-local  cuda-cusolver-9-2 9.2.88-1 [31.1 MB]
# Get:29 file:/var/cuda-repo-9-2-local  cuda-cusolver-dev-9-2 9.2.88-1 [8,184 kB]
# Get:30 file:/var/cuda-repo-9-2-local  cuda-cublas-9-2 9.2.88-1 [24.9 MB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2 amd64 1:2.25-1.2 [13.0 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libargon2-0 amd64 0~20161029-1.1 [19.9 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdevmapper1.02.1 amd64 2:1.02.145-4.1ubuntu3.18.04.3 [127 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcryptsetup12 amd64 2:2.0.2-1ubuntu1.2 [134 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libidn11 amd64 1.33-2.1ubuntu1.2 [46.6 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libip4tc0 amd64 1.6.1-2ubuntu2 [19.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd amd64 237-3ubuntu10.52 [2,913 kB]
# Get:38 file:/var/cuda-repo-9-2-local  cuda-cublas-dev-9-2 9.2.88-1 [49.1 MB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd-sysv amd64 237-3ubuntu10.52 [13.6 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dmsetup amd64 2:1.02.145-4.1ubuntu3.18.04.3 [74.4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss-systemd amd64 237-3ubuntu10.52 [105 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-systemd amd64 237-3ubuntu10.52 [107 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 networkd-dispatcher all 1.7-0ubuntu3.3 [13.3 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udev amd64 237-3ubuntu10.52 [1,102 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-gobject-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jdk-headless amd64 11.0.13+8-0ubuntu1~18.04 [220 MB]
# Get:48 file:/var/cuda-repo-9-2-local  cuda-cufft-9-2 9.2.88-1 [51.5 MB]
# Get:49 file:/var/cuda-repo-9-2-local  cuda-cufft-dev-9-2 9.2.88-1 [106 MB]
# Get:50 file:/var/cuda-repo-9-2-local  cuda-curand-9-2 9.2.88-1 [38.8 MB]
# Get:51 file:/var/cuda-repo-9-2-local  cuda-curand-dev-9-2 9.2.88-1 [57.8 MB]
# Get:52 file:/var/cuda-repo-9-2-local  cuda-cusparse-9-2 9.2.88-1 [27.6 MB]
# Get:53 file:/var/cuda-repo-9-2-local  cuda-cusparse-dev-9-2 9.2.88-1 [27.8 MB]
# Get:54 file:/var/cuda-repo-9-2-local  cuda-npp-9-2 9.2.88-1 [52.1 MB]
# Get:55 file:/var/cuda-repo-9-2-local  cuda-npp-dev-9-2 9.2.88-1 [52.0 MB]
# Get:56 file:/var/cuda-repo-9-2-local  cuda-nvml-dev-9-2 9.2.88-1 [49.4 kB]
# Get:57 file:/var/cuda-repo-9-2-local  cuda-nvgraph-9-2 9.2.88-1 [11.7 MB]
# Get:58 file:/var/cuda-repo-9-2-local  cuda-nvgraph-dev-9-2 9.2.88-1 [30.0 MB]
# Get:59 file:/var/cuda-repo-9-2-local  cuda-visual-tools-9-2 9.2.88-1 [396 MB]
# Get:60 file:/var/cuda-repo-9-2-local  cuda-tools-9-2 9.2.88-1 [2,486 B]
# Get:61 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre-headless amd64 11.0.13+8-0ubuntu1~18.04 [37.2 MB]
# Get:62 file:/var/cuda-repo-9-2-local  cuda-samples-9-2 9.2.88-1 [76.3 MB]
# Get:63 file:/var/cuda-repo-9-2-local  cuda-documentation-9-2 9.2.88-1 [50.4 MB]
# Get:64 file:/var/cuda-repo-9-2-local  cuda-libraries-dev-9-2 9.2.88-1 [2,598 B]
# Get:65 file:/var/cuda-repo-9-2-local  cuda-toolkit-9-2 9.2.88-1 [2,828 B]
# Get:66 file:/var/cuda-repo-9-2-local  cuda-libraries-9-2 9.2.88-1 [2,568 B]
# Get:67 file:/var/cuda-repo-9-2-local  cuda-runtime-9-2 9.2.88-1 [2,530 B]
# Get:68 file:/var/cuda-repo-9-2-local  cuda-demo-suite-9-2 9.2.88-1 [3,889 kB]
# Get:69 file:/var/cuda-repo-9-2-local  cuda-9-2 9.2.88-1 [2,560 B]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.13+8-0ubuntu1~18.04 [174 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 default-jre amd64 2:1.11-68ubuntu1~18.04.1 [1,076 B]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-headers all 2:1.1.2-2 [54.3 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmu-dev amd64 2:1.1.2-2 [49.0 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-common-495 all 495.44-0ubuntu0.18.04.1 [9,260 B]
# Get:79 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-compute-495 amd64 495.44-0ubuntu0.18.04.1 [31.3 MB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-decode-495 amd64 495.44-0ubuntu0.18.04.1 [1,267 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-encode-495 amd64 495.44-0ubuntu0.18.04.1 [40.8 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-fbc1-495 amd64 495.44-0ubuntu0.18.04.1 [45.7 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-gl-495 amd64 495.44-0ubuntu0.18.04.1 [150 MB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-compute-utils-495 amd64 495.44-0ubuntu0.18.04.1 [105 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dkms all 2.3-3ubuntu9.7 [68.1 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-kernel-source-495 amd64 495.44-0ubuntu0.18.04.1 [27.1 MB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-kernel-common-495 amd64 495.44-0ubuntu0.18.04.1 [18.8 MB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-dkms-495 amd64 495.44-0ubuntu0.18.04.1 [28.2 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-extra-495 amd64 495.44-0ubuntu0.18.04.1 [45.1 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-utils-495 amd64 495.44-0ubuntu0.18.04.1 [372 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 libnvidia-cfg1-495 amd64 495.44-0ubuntu0.18.04.1 [78.2 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 x11-xkb-utils amd64 7.7+3ubuntu0.18.04.1 [160 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.10 [26.9 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-core-hwe-18.04 amd64 2:1.20.8-2ubuntu2.2~18.04.6 [1,335 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 xserver-xorg-video-nvidia-495 amd64 495.44-0ubuntu0.18.04.1 [1,387 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 nvidia-driver-495 amd64 495.44-0ubuntu0.18.04.1 [448 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-xkit all 0.5.0ubuntu2 [18.6 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-agent-1-0 amd64 0.105-20ubuntu0.18.04.5 [14.9 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpolkit-backend-1-0 amd64 0.105-20ubuntu0.18.04.5 [36.3 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 policykit-1 amd64 0.105-20ubuntu0.18.04.5 [53.5 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/main amd64 policykit-1-gnome amd64 0.105-6ubuntu2 [24.0 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/main amd64 screen-resolution-extra all 0.17.3 [11.7 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjansson4 amd64 2.11-1 [29.3 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfakeroot amd64 1.22-2ubuntu1 [25.9 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 fakeroot amd64 1.22-2ubuntu1 [62.3 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nvidia-prime all 0.8.16~0.18.04.1 [9,224 B]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Fetched 508 MB in 44s (11.5 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package keyboard-configuration.
# (Reading database ... 111758 files and directories currently installed.)
# Preparing to unpack .../0-keyboard-configuration_1.178ubuntu2.9_all.deb ...
# Unpacking keyboard-configuration (1.178ubuntu2.9) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../1-libcap2_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libargon2-0:amd64.
# Preparing to unpack .../2-libargon2-0_0~20161029-1.1_amd64.deb ...
# Unpacking libargon2-0:amd64 (0~20161029-1.1) ...
# Selecting previously unselected package libdevmapper1.02.1:amd64.
# Preparing to unpack .../3-libdevmapper1.02.1_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libcryptsetup12:amd64.
# Preparing to unpack .../4-libcryptsetup12_2%3a2.0.2-1ubuntu1.2_amd64.deb ...
# Unpacking libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.2) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../5-libidn11_1.33-2.1ubuntu1.2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Selecting previously unselected package libip4tc0:amd64.
# Preparing to unpack .../6-libip4tc0_1.6.1-2ubuntu2_amd64.deb ...
# Unpacking libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Setting up libcap2:amd64 (1:2.25-1.2) ...
# Setting up libargon2-0:amd64 (0~20161029-1.1) ...
# Setting up libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up libcryptsetup12:amd64 (2:2.0.2-1ubuntu1.2) ...
# Setting up libidn11:amd64 (1.33-2.1ubuntu1.2) ...
# Setting up libip4tc0:amd64 (1.6.1-2ubuntu2) ...
# Selecting previously unselected package systemd.
# (Reading database ... 111810 files and directories currently installed.)
# Preparing to unpack .../systemd_237-3ubuntu10.52_amd64.deb ...
# Unpacking systemd (237-3ubuntu10.52) ...
# Setting up systemd (237-3ubuntu10.52) ...
# Selecting previously unselected package systemd-sysv.
# (Reading database ... 112492 files and directories currently installed.)
# Preparing to unpack .../000-systemd-sysv_237-3ubuntu10.52_amd64.deb ...
# Unpacking systemd-sysv (237-3ubuntu10.52) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../001-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package dmsetup.
# Preparing to unpack .../002-dmsetup_2%3a1.02.145-4.1ubuntu3.18.04.3_amd64.deb ...
# Unpacking dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Selecting previously unselected package libnss-systemd:amd64.
# Preparing to unpack .../003-libnss-systemd_237-3ubuntu10.52_amd64.deb ...
# Unpacking libnss-systemd:amd64 (237-3ubuntu10.52) ...
# Selecting previously unselected package libpam-systemd:amd64.
# Preparing to unpack .../004-libpam-systemd_237-3ubuntu10.52_amd64.deb ...
# Unpacking libpam-systemd:amd64 (237-3ubuntu10.52) ...
# Selecting previously unselected package networkd-dispatcher.
# Preparing to unpack .../005-networkd-dispatcher_1.7-0ubuntu3.3_all.deb ...
# Unpacking networkd-dispatcher (1.7-0ubuntu3.3) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../006-udev_237-3ubuntu10.52_amd64.deb ...
# Unpacking udev (237-3ubuntu10.52) ...
# Selecting previously unselected package libpolkit-gobject-1-0:amd64.
# Preparing to unpack .../007-libpolkit-gobject-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package cuda-license-9-2.
# Preparing to unpack .../008-cuda-license-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-license-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-misc-headers-9-2.
# Preparing to unpack .../009-cuda-misc-headers-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-misc-headers-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvcc-9-2.
# Preparing to unpack .../010-cuda-nvcc-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvcc-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cuobjdump-9-2.
# Preparing to unpack .../011-cuda-cuobjdump-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cuobjdump-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvprune-9-2.
# Preparing to unpack .../012-cuda-nvprune-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvprune-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-compiler-9-2.
# Preparing to unpack .../013-cuda-compiler-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-compiler-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvdisasm-9-2.
# Preparing to unpack .../014-cuda-nvdisasm-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvdisasm-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-gdb-9-2.
# Preparing to unpack .../015-cuda-gdb-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-gdb-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvprof-9-2.
# Preparing to unpack .../016-cuda-nvprof-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvprof-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-memcheck-9-2.
# Preparing to unpack .../017-cuda-memcheck-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-memcheck-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cudart-9-2.
# Preparing to unpack .../018-cuda-cudart-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cudart-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-driver-dev-9-2.
# Preparing to unpack .../019-cuda-driver-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-driver-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cudart-dev-9-2.
# Preparing to unpack .../020-cuda-cudart-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cudart-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cupti-9-2.
# Preparing to unpack .../021-cuda-cupti-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cupti-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-gpu-library-advisor-9-2.
# Preparing to unpack .../022-cuda-gpu-library-advisor-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-gpu-library-advisor-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvtx-9-2.
# Preparing to unpack .../023-cuda-nvtx-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvtx-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-command-line-tools-9-2.
# Preparing to unpack .../024-cuda-command-line-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-command-line-tools-9-2 (9.2.88-1) ...
# Preparing to unpack .../025-openjdk-11-jdk-headless_11.0.13+8-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jdk-headless:amd64 (11.0.13+8-0ubuntu1~18.04) over (11.0.11+9-0ubuntu2~18.04) ...
# Preparing to unpack .../026-openjdk-11-jre-headless_11.0.13+8-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.13+8-0ubuntu1~18.04) over (11.0.11+9-0ubuntu2~18.04) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../027-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../028-openjdk-11-jre_11.0.13+8-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.13+8-0ubuntu1~18.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../029-default-jre_2%3a1.11-68ubuntu1~18.04.1_amd64.deb ...
# Unpacking default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Selecting previously unselected package cuda-nsight-9-2.
# Preparing to unpack .../030-cuda-nsight-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nsight-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvvp-9-2.
# Preparing to unpack .../031-cuda-nvvp-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvvp-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvrtc-9-2.
# Preparing to unpack .../032-cuda-nvrtc-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvrtc-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-9-2.
# Preparing to unpack .../033-cuda-nvrtc-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusolver-9-2.
# Preparing to unpack .../034-cuda-cusolver-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusolver-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusolver-dev-9-2.
# Preparing to unpack .../035-cuda-cusolver-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cublas-9-2.
# Preparing to unpack .../036-cuda-cublas-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cublas-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cublas-dev-9-2.
# Preparing to unpack .../037-cuda-cublas-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cublas-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cufft-9-2.
# Preparing to unpack .../038-cuda-cufft-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cufft-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cufft-dev-9-2.
# Preparing to unpack .../039-cuda-cufft-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cufft-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-curand-9-2.
# Preparing to unpack .../040-cuda-curand-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-curand-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-curand-dev-9-2.
# Preparing to unpack .../041-cuda-curand-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-curand-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusparse-9-2.
# Preparing to unpack .../042-cuda-cusparse-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusparse-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-cusparse-dev-9-2.
# Preparing to unpack .../043-cuda-cusparse-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-npp-9-2.
# Preparing to unpack .../044-cuda-npp-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-npp-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-npp-dev-9-2.
# Preparing to unpack .../045-cuda-npp-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-npp-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvml-dev-9-2.
# Preparing to unpack .../046-cuda-nvml-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvml-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvgraph-9-2.
# Preparing to unpack .../047-cuda-nvgraph-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvgraph-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-9-2.
# Preparing to unpack .../048-cuda-nvgraph-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-visual-tools-9-2.
# Preparing to unpack .../049-cuda-visual-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-visual-tools-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-tools-9-2.
# Preparing to unpack .../050-cuda-tools-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-tools-9-2 (9.2.88-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../051-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../052-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# Selecting previously unselected package libxmu-headers.
# Preparing to unpack .../053-libxmu-headers_2%3a1.1.2-2_all.deb ...
# Unpacking libxmu-headers (2:1.1.2-2) ...
# Selecting previously unselected package libxmu-dev:amd64.
# Preparing to unpack .../054-libxmu-dev_2%3a1.1.2-2_amd64.deb ...
# Unpacking libxmu-dev:amd64 (2:1.1.2-2) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../055-libxi-dev_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package cuda-samples-9-2.
# Preparing to unpack .../056-cuda-samples-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-samples-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-documentation-9-2.
# Preparing to unpack .../057-cuda-documentation-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-documentation-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-libraries-dev-9-2.
# Preparing to unpack .../058-cuda-libraries-dev-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-libraries-dev-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-toolkit-9-2.
# Preparing to unpack .../059-cuda-toolkit-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-toolkit-9-2 (9.2.88-1) ...
# Selecting previously unselected package libnvidia-common-495.
# Preparing to unpack .../060-libnvidia-common-495_495.44-0ubuntu0.18.04.1_all.deb ...
# Unpacking libnvidia-common-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../061-libnvidia-compute-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-decode-495:amd64.
# Preparing to unpack .../062-libnvidia-decode-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-decode-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-encode-495:amd64.
# Preparing to unpack .../063-libnvidia-encode-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-encode-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-fbc1-495:amd64.
# Preparing to unpack .../064-libnvidia-fbc1-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-fbc1-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-gl-495:amd64.
# Preparing to unpack .../065-libnvidia-gl-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-gl-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-compute-utils-495.
# Preparing to unpack .../066-nvidia-compute-utils-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-compute-utils-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../067-dkms_2.3-3ubuntu9.7_all.deb ...
# Unpacking dkms (2.3-3ubuntu9.7) ...
# Selecting previously unselected package nvidia-kernel-source-495.
# Preparing to unpack .../068-nvidia-kernel-source-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-source-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-kernel-common-495.
# Preparing to unpack .../069-nvidia-kernel-common-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-common-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-dkms-495.
# Preparing to unpack .../070-nvidia-dkms-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-dkms-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-extra-495:amd64.
# Preparing to unpack .../071-libnvidia-extra-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-extra-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-utils-495.
# Preparing to unpack .../072-nvidia-utils-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-utils-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnvidia-cfg1-495:amd64.
# Preparing to unpack .../073-libnvidia-cfg1-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libnvidia-cfg1-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../074-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../075-x11-xkb-utils_7.7+3ubuntu0.18.04.1_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../076-xserver-common_2%3a1.19.6-1ubuntu4.10_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.10) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../077-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../078-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package xserver-xorg-core-hwe-18.04.
# Preparing to unpack .../079-xserver-xorg-core-hwe-18.04_2%3a1.20.8-2ubuntu2.2~18.04.6_amd64.deb ...
# Unpacking xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.6) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-495.
# Preparing to unpack .../080-xserver-xorg-video-nvidia-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-driver-495.
# Preparing to unpack .../081-nvidia-driver-495_495.44-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking nvidia-driver-495 (495.44-0ubuntu0.18.04.1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../082-nvidia-modprobe_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (495.29.05-0ubuntu1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../083-python3-xkit_0.5.0ubuntu2_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu2) ...
# Selecting previously unselected package libpolkit-agent-1-0:amd64.
# Preparing to unpack .../084-libpolkit-agent-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package libpolkit-backend-1-0:amd64.
# Preparing to unpack .../085-libpolkit-backend-1-0_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package policykit-1.
# Preparing to unpack .../086-policykit-1_0.105-20ubuntu0.18.04.5_amd64.deb ...
# Unpacking policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Selecting previously unselected package policykit-1-gnome.
# Preparing to unpack .../087-policykit-1-gnome_0.105-6ubuntu2_amd64.deb ...
# Unpacking policykit-1-gnome (0.105-6ubuntu2) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../088-screen-resolution-extra_0.17.3_all.deb ...
# Unpacking screen-resolution-extra (0.17.3) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../089-libjansson4_2.11-1_amd64.deb ...
# Unpacking libjansson4:amd64 (2.11-1) ...
# Selecting previously unselected package libxnvctrl0:amd64.
# Preparing to unpack .../090-libxnvctrl0_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (495.29.05-0ubuntu1) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../091-nvidia-settings_495.29.05-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (495.29.05-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers-495.
# Preparing to unpack .../092-cuda-drivers-495_495.29.05-1_amd64.deb ...
# Unpacking cuda-drivers-495 (495.29.05-1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../093-cuda-drivers_495.29.05-1_amd64.deb ...
# Unpacking cuda-drivers (495.29.05-1) ...
# Selecting previously unselected package cuda-libraries-9-2.
# Preparing to unpack .../094-cuda-libraries-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-libraries-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-runtime-9-2.
# Preparing to unpack .../095-cuda-runtime-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-runtime-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-demo-suite-9-2.
# Preparing to unpack .../096-cuda-demo-suite-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-demo-suite-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-9-2.
# Preparing to unpack .../097-cuda-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-9-2 (9.2.88-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../098-libfakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.22-2ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../099-fakeroot_1.22-2ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.22-2ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../100-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../101-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../102-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../103-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../104-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../105-nvidia-prime_0.8.16~0.18.04.1_all.deb ...
# Unpacking nvidia-prime (0.8.16~0.18.04.1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../106-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.4-2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../107-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../108-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# Unpacking xfonts-base (1:1.0.4+nmu1) ...
# Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# Setting up libnss-systemd:amd64 (237-3ubuntu10.52) ...
# First installation detected...
# Checking NSS setup...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up keyboard-configuration (1.178ubuntu2.9) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up nvidia-prime (0.8.16~0.18.04.1) ...
# Setting up libnvidia-common-495 (495.44-0ubuntu0.18.04.1) ...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up systemd-sysv (237-3ubuntu10.52) ...
# Setting up libnvidia-gl-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up libxmu-headers (2:1.1.2-2) ...
# Setting up libnvidia-compute-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up libjansson4:amd64 (2.11-1) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.13+8-0ubuntu1~18.04) ...
# Installing new version of config file /etc/java-11-openjdk/security/java.security ...
# Setting up openjdk-11-jdk-headless:amd64 (11.0.13+8-0ubuntu1~18.04) ...
# Setting up libnvidia-fbc1-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up cuda-license-9-2 (9.2.88-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-9.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up libnvidia-extra-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up xfonts-encodings (1:1.0.4-2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up cuda-nvprune-9-2 (9.2.88-1) ...
# Setting up libnvidia-cfg1-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up dkms (2.3-3ubuntu9.7) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up udev (237-3ubuntu10.52) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up cuda-cudart-9-2 (9.2.88-1) ...
# Setting up libfakeroot:amd64 (1.22-2ubuntu1) ...
# Setting up nvidia-modprobe (495.29.05-0ubuntu1) ...
# Setting up cuda-nvprof-9-2 (9.2.88-1) ...
# Setting up cuda-nvrtc-9-2 (9.2.88-1) ...
# Setting up cuda-nvtx-9-2 (9.2.88-1) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# Setting up dmsetup (2:1.02.145-4.1ubuntu3.18.04.3) ...
# Setting up nvidia-utils-495 (495.44-0ubuntu0.18.04.1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up nvidia-kernel-common-495 (495.44-0ubuntu0.18.04.1) ...
# Created symlink /etc/systemd/system/systemd-hibernate.service.requires/nvidia-hibernate.service → /lib/systemd/system/nvidia-hibernate.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.requires/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-hibernate.service.requires/nvidia-resume.service → /lib/systemd/system/nvidia-resume.service.
# Created symlink /etc/systemd/system/systemd-suspend.service.requires/nvidia-suspend.service → /lib/systemd/system/nvidia-suspend.service.
# Setting up cuda-cusolver-9-2 (9.2.88-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up cuda-nvml-dev-9-2 (9.2.88-1) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up libxnvctrl0:amd64 (495.29.05-0ubuntu1) ...
# Setting up cuda-cufft-9-2 (9.2.88-1) ...
# Setting up nvidia-kernel-source-495 (495.44-0ubuntu0.18.04.1) ...
# Setting up networkd-dispatcher (1.7-0ubuntu3.3) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/networkd-dispatcher.service → /lib/systemd/system/networkd-dispatcher.service.
# Setting up libpolkit-gobject-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up python3-xkit (0.5.0ubuntu2) ...
# Setting up openjdk-11-jre:amd64 (11.0.13+8-0ubuntu1~18.04) ...
# Setting up cuda-npp-9-2 (9.2.88-1) ...
# Setting up nvidia-dkms-495 (495.44-0ubuntu0.18.04.1) ...
# Loading new nvidia-495.44 DKMS files...
# It is likely that 5.4.144+ belongs to a chroot's host
# Building for 4.15.0-163-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-163-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-163-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-163-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-163-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-163-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-163-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up cuda-misc-headers-9-2 (9.2.88-1) ...
# Setting up cuda-memcheck-9-2 (9.2.88-1) ...
# Setting up cuda-npp-dev-9-2 (9.2.88-1) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.10) ...
# Setting up cuda-nvdisasm-9-2 (9.2.88-1) ...
# Setting up nvidia-compute-utils-495 (495.44-0ubuntu0.18.04.1) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 104) ...
# Adding new group `nvidia-persistenced' (GID 108) ...
# Adding new user `nvidia-persistenced' (UID 104) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Setting up libpam-systemd:amd64 (237-3ubuntu10.52) ...
# Setting up cuda-nvrtc-dev-9-2 (9.2.88-1) ...
# Setting up cuda-driver-dev-9-2 (9.2.88-1) ...
# Setting up cuda-curand-9-2 (9.2.88-1) ...
# Setting up cuda-cusolver-dev-9-2 (9.2.88-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up libpolkit-agent-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up default-jre (2:1.11-68ubuntu1~18.04.1) ...
# Setting up libnvidia-decode-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up cuda-nsight-9-2 (9.2.88-1) ...
# Setting up cuda-cublas-9-2 (9.2.88-1) ...
# Setting up cuda-cuobjdump-9-2 (9.2.88-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up cuda-cusparse-9-2 (9.2.88-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up cuda-nvgraph-9-2 (9.2.88-1) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up cuda-gpu-library-advisor-9-2 (9.2.88-1) ...
# Setting up fakeroot (1.22-2ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up cuda-gdb-9-2 (9.2.88-1) ...
# Setting up libpolkit-backend-1-0:amd64 (0.105-20ubuntu0.18.04.5) ...
# Setting up cuda-cudart-dev-9-2 (9.2.88-1) ...
# Setting up cuda-cufft-dev-9-2 (9.2.88-1) ...
# Setting up cuda-libraries-9-2 (9.2.88-1) ...
# Setting up cuda-cusparse-dev-9-2 (9.2.88-1) ...
# Setting up cuda-nvcc-9-2 (9.2.88-1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up xserver-xorg-core-hwe-18.04 (2:1.20.8-2ubuntu2.2~18.04.6) ...
# Setting up cuda-cupti-9-2 (9.2.88-1) ...
# Setting up cuda-cublas-dev-9-2 (9.2.88-1) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up cuda-nvgraph-dev-9-2 (9.2.88-1) ...
# Setting up libnvidia-encode-495:amd64 (495.44-0ubuntu0.18.04.1) ...
# Setting up cuda-command-line-tools-9-2 (9.2.88-1) ...
# Setting up cuda-curand-dev-9-2 (9.2.88-1) ...
# Setting up cuda-nvvp-9-2 (9.2.88-1) ...
# Setting up policykit-1 (0.105-20ubuntu0.18.04.5) ...
# Setting up cuda-visual-tools-9-2 (9.2.88-1) ...
# Setting up xserver-xorg-video-nvidia-495 (495.44-0ubuntu0.18.04.1) ...
# Setting up cuda-compiler-9-2 (9.2.88-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up policykit-1-gnome (0.105-6ubuntu2) ...
# Setting up screen-resolution-extra (0.17.3) ...
# Setting up cuda-libraries-dev-9-2 (9.2.88-1) ...
# Setting up cuda-samples-9-2 (9.2.88-1) ...
# Setting up cuda-documentation-9-2 (9.2.88-1) ...
# Setting up cuda-tools-9-2 (9.2.88-1) ...
# Setting up cuda-toolkit-9-2 (9.2.88-1) ...
# Setting up nvidia-driver-495 (495.44-0ubuntu0.18.04.1) ...
# Setting up nvidia-settings (495.29.05-0ubuntu1) ...
# Setting up cuda-drivers-495 (495.29.05-1) ...
# Setting up cuda-drivers (495.29.05-1) ...
# Setting up cuda-runtime-9-2 (9.2.88-1) ...
# Setting up cuda-demo-suite-9-2 (9.2.88-1) ...
# Setting up cuda-9-2 (9.2.88-1) ...
# Processing triggers for systemd (237-3ubuntu10.52) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Wed_Apr_11_23:16:29_CDT_2018
# Cuda compilation tools, release 9.2, V9.2.88
# Collecting git+git://github.com/andreinechaev/nvcc4jupyter.git
#   Cloning git://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-effyqa_5
#   Running command git clone -q git://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-effyqa_5
# Building wheels for collected packages: NVCCPlugin
#   Building wheel for NVCCPlugin (setup.py) ... done
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4305 sha256=4060406609f634de042bc08c3294d508ef5cbe5daab4c2853fbc9a17c8ab889a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0mkpekc6/wheels/c5/2b/c0/87008e795a14bbcdfc7c846a00d06981916331eb980b6c8bdf
# Successfully built NVCCPlugin
# Installing collected packages: NVCCPlugin
# Successfully installed NVCCPlugin-0.0.2
# created output directory at /content/src
# Out bin /content/result.out

# %%
# %%cu
# #include <iostream>
# #include <stdio.h>
# #include <cuda.h>
# #include <math.h>
# #include <chrono>
# #include <bits/stdc++.h>
#
# using namespace std;
# using namespace std::chrono;
#
# // # calculate maximum
# __global__
# void maximum(int *input) {
#     int tid = threadIdx.x;
#     int step_size = 1;
#     int number_of_threads = blockDim.x;
#
#     while(number_of_threads>0) {
#         if(tid < number_of_threads) {
#             int first = tid*step_size*2;
#             int second = first + step_size;
#             if(input[second] > input[first])
#               input[first] = input[second];
#         }
#         step_size <<= 1;
#         if(number_of_threads == 1)
#           number_of_threads = 0;
#         else
#           number_of_threads = ceil((double)number_of_threads / 2);
#     }
# }
#
# // # calculate minimum
# __global__
# void minimum(int *input, int n) {
#     int tid = threadIdx.x;
#     int step_size = 1;
#     int number_of_threads = blockDim.x;
#
#     while(number_of_threads>0) {
#         if(tid < number_of_threads) {
#             int first = tid*step_size*2;
#             int second = first + step_size;
#             if((first < n && second < n) && input[second] < input[first])
#               input[first] = input[second];
#         }
#         step_size <<= 1;
#         if(number_of_threads == 1)
#           number_of_threads = 0;
#         else
#           number_of_threads = ceil((double)number_of_threads / 2);
#     }
# }
#
# // # calculate sum
# __global__
# void gpu_sum(int *input) {
#     const int tid = threadIdx.x;
#     int step_size = 1;
#     int number_of_threads = blockDim.x;
#
#     while(number_of_threads > 0) {
#         if(tid < number_of_threads) {
#             int first = tid * step_size * 2;
#             int second = first + step_size;
#             input[first] += input[second];
#         }
#         step_size <<= 1;
#         if(number_of_threads == 1)
#           number_of_threads = 0;
#         else
#           number_of_threads = ceil((double)number_of_threads / 2);
#     }
#     if(tid == 0) {
#         int first = tid * step_size * 2;
#         int second = first + step_size;
#         input[first] += input[second];
#     }
# }
#
# // # calculate square of mean difference
# __global__
# void mean_diff_sq(float *input, float mean) {
#     input[threadIdx.x] -= mean;
#     input[threadIdx.x] *= input[threadIdx.x];
# }
#
# // # convert array from int to float
# void copy_int_to_float(float *dest, int *src, int size){
#     for(int i = 0; i < size; i++)
#         dest[i] = (float)src[i];
# }
#
# // # calculate standard deviation
# __global__
# void gpu_sd(float *input) {
#     const int tid = threadIdx.x;
#     int step_size = 1;
#     int number_of_threads = blockDim.x;
#
#     while(number_of_threads > 0) {
#         if(tid < number_of_threads) {
#             int first = tid * step_size * 2;
#             int second = first + step_size;
#             input[first] += input[second];
#         }
#         step_size <<= 1;
#         if(number_of_threads == 1)
#           number_of_threads = 0;
#         else
#           number_of_threads = ceil((double)number_of_threads / 2);
#     }
#     if(tid == 0) {
#         int first = tid * step_size * 2;
#         int second = first + step_size;
#         input[first] += input[second];
#     }
# }
#
# long cpu_sum(int *input, int n) {
#     long sum = 0;
#     for(int i = 0 ; i < n ; i++) {
#         sum += input[i];
#     }
#     return sum;
# }
#
# long cpu_min(int *arr, int n) {
#     int min =  arr[0];
#     for(int i = 1 ; i < n ; i++) {
#         if(arr[i] < min)
#           min = arr[i];
#     }
#     return min;
# }
#
# long cpu_max(int *arr, int n) {
#     int max =  arr[0];
#     for(int i = 1 ; i < n ; i++) {
#         if(arr[i] > max)
#           max = arr[i];
#     }
#     return max;
# }
#
# double cpu_sd(int *arr, int n, float mean) {
#     float *arr_std = new float[n];
#     for(int i = 0 ; i < n ; i++) {
#         arr_std[i] = pow(((float)arr[i] - mean),2);
#     }
#     double total = 0;
#     for(int i = 0 ; i < n ; i++) {
#         total += arr_std[i];
#     }
#     total = total / n;
#     return sqrt(total);
# }
#
# void random_init(int *arr, int n) {
#     for(int i = 0 ; i < n ; i++) {
#         arr[i] = rand()%1000;
#     }
# }
#
# int main() {
#     int *d;   // # array for device
#     int n = 500;
#     int *arr = new int[n];
#     int result;   // # display result on host side
#     int size = n * sizeof(int);
#     random_init(arr, n);   // # generate random array elements
#
#     // # display array
#     cout<<"Input Array: [";
#     for(int i = 0 ; i < n ; i++) {
#         cout<<arr[i]<<", ";
#     }
#     cout<<"]"<<endl;
#
#     cudaMalloc((void **)&d, size);   // # allocate space for device array
#     cudaMemcpy(d, arr, size, cudaMemcpyHostToDevice);    // # copy arr into d (from host to device)
#
#     gpu_sum<<<1, n/2>>>(d);    // # calculate sum of array elements
#
#     cudaMemcpy(&result, d, sizeof(int), cudaMemcpyDeviceToHost);   // # copy d into result (from device to host)
#     cout<<"======================================="<<endl;
#
#     // # display sum and mean
#     cout<<"GPU Sum is: "<<result<<endl;
#     float mean = (double)result/n;
#     cout<<"GPU Mean is: "<<mean<<endl;
#
#     float *arr_float = new float[n];    // # float array
#     float *arr_std, std;    // # arr_std is device array, std is host result
#
#     cudaMalloc((void **)&arr_std, n*sizeof(float));  // # allocate space for arr_std
#     copy_int_to_float(arr_float, arr, n);   // # convert array to float
#     cudaMemcpy(arr_std, arr_float, n*sizeof(float), cudaMemcpyHostToDevice);  // # copy arr_float into arr_std
#
#     mean_diff_sq<<<1, n>>>(arr_std, mean);    // # calculate mean difference square
#
#     auto start = high_resolution_clock::now();
#     gpu_sd<<<1, n/2>>>(arr_std);    // # calculate sum
#     auto stop = high_resolution_clock::now();
#     auto duration = duration_cast<microseconds>(stop - start);
#
#     // # display standard deviation
#     cudaMemcpy(&std,arr_std,sizeof(float),cudaMemcpyDeviceToHost);
#     cout<<"GPU Standard Deviation: "<<sqrt(std/n)<<", Time taken: " << duration.count() << "ms" << endl;
#     cout<<"======================================="<<endl;
#
#     // # cpu calculations
#     result = cpu_sum(arr,n);
#     cout<<"CPU Sum is: "<<result<< endl;
#
#     mean = (float)result/n;
#     cout<<"CPU Mean is: "<<mean<<endl;
#
#     start = high_resolution_clock::now();
#     std = cpu_sd(arr, n, mean);
#     stop = high_resolution_clock::now();
#     duration = duration_cast<microseconds>(stop - start);
#     cout<<"CPU Standard Deviation: "<<std<<", Time taken: " << duration.count() << "ms" << endl;
#     cout<<"======================================="<<endl;
#
#     // # calculate minimum
#     cudaMemcpy(d,arr,size,cudaMemcpyHostToDevice);
#     minimum<<<1,n/2>>>(d,n);
#     cudaMemcpy(&result,d,sizeof(int),cudaMemcpyDeviceToHost);
#     cout<<"GPU Min is: "<<result<<endl;
#
#     // # calculate minimum cpu
#     result = cpu_min(arr,n);
#     cout<<"CPU Min is: "<<result<<endl;
#     cout<<"======================================="<<endl;
#
#     // # calculate maximum
#     cudaMemcpy(d,arr,size,cudaMemcpyHostToDevice);
#     maximum<<<1,n/2>>>(d);
#     cudaMemcpy(&result,d,sizeof(int),cudaMemcpyDeviceToHost);
#     cout<<"GPU Max is: "<<result<<endl;
#
#     // # calculate maximum cpu
#     result = cpu_max(arr,n);
#     cout<<"CPU Max is: "<<result<<"\n";
#     cout<<"======================================="<<endl;
#     return 0;
# }
# Out:
# Input Array: [383, 886, 777, 915, 793, 335, 386, 492, 649, 421, 362, 27, 690, 59, 763, 926, 540, 426, 172, 736, 211, 368, 567, 429, 782, 530, 862, 123, 67, 135, 929, 802, 22, 58, 69, 167, 393, 456, 11, 42, 229, 373, 421, 919, 784, 537, 198, 324, 315, 370, 413, 526, 91, 980, 956, 873, 862, 170, 996, 281, 305, 925, 84, 327, 336, 505, 846, 729, 313, 857, 124, 895, 582, 545, 814, 367, 434, 364, 43, 750, 87, 808, 276, 178, 788, 584, 403, 651, 754, 399, 932, 60, 676, 368, 739, 12, 226, 586, 94, 539, 795, 570, 434, 378, 467, 601, 97, 902, 317, 492, 652, 756, 301, 280, 286, 441, 865, 689, 444, 619, 440, 729, 31, 117, 97, 771, 481, 675, 709, 927, 567, 856, 497, 353, 586, 965, 306, 683, 219, 624, 528, 871, 732, 829, 503, 19, 270, 368, 708, 715, 340, 149, 796, 723, 618, 245, 846, 451, 921, 555, 379, 488, 764, 228, 841, 350, 193, 500, 34, 764, 124, 914, 987, 856, 743, 491, 227, 365, 859, 936, 432, 551, 437, 228, 275, 407, 474, 121, 858, 395, 29, 237, 235, 793, 818, 428, 143, 11, 928, 529, 776, 404, 443, 763, 613, 538, 606, 840, 904, 818, 128, 688, 369, 917, 917, 996, 324, 743, 470, 183, 490, 499, 772, 725, 644, 590, 505, 139, 954, 786, 669, 82, 542, 464, 197, 507, 355, 804, 348, 611, 622, 828, 299, 343, 746, 568, 340, 422, 311, 810, 605, 801, 661, 730, 878, 305, 320, 736, 444, 626, 522, 465, 708, 416, 282, 258, 924, 637, 62, 624, 600, 36, 452, 899, 379, 550, 468, 71, 973, 131, 881, 930, 933, 894, 660, 163, 199, 981, 899, 996, 959, 773, 813, 668, 190, 95, 926, 466, 84, 340, 90, 684, 376, 542, 936, 107, 445, 756, 179, 418, 887, 412, 348, 172, 659, 9, 336, 210, 342, 587, 206, 301, 713, 372, 321, 255, 819, 599, 721, 904, 939, 811, 940, 667, 705, 228, 127, 150, 984, 658, 920, 224, 422, 269, 396, 81, 630, 84, 292, 972, 672, 850, 625, 385, 222, 299, 640, 42, 898, 713, 298, 190, 524, 590, 209, 581, 819, 336, 732, 155, 994, 4, 379, 769, 273, 776, 850, 255, 860, 142, 579, 884, 993, 205, 621, 567, 504, 613, 961, 754, 326, 259, 944, 202, 202, 506, 784, 21, 842, 868, 528, 189, 872, 908, 958, 498, 36, 808, 753, 248, 303, 333, 133, 648, 890, 754, 567, 746, 368, 529, 500, 46, 788, 797, 249, 990, 303, 33, 363, 497, 253, 892, 686, 125, 152, 996, 975, 188, 157, 729, 436, 460, 414, 921, 460, 304, 28, 27, 50, 748, 556, 902, 794, 697, 699, 43, 39, 2, 428, 403, 500, 681, 647, 538, 159, 151, 535, 134, 339, 692, 215, 127, 504, 629, 49, 964, 285, 429, 343, 335, 177, 900, 238, 971, 949, 289, 367, 988, 292, 795, 743, 144, 829, 390, 682, 340, 541, 569, 826, 232, ]
# =======================================
# GPU Sum is: 255726
# GPU Mean is: 511.452
# GPU Standard Deviation: 283.74, Time taken: 3ms
# =======================================
# CPU Sum is: 255726
# CPU Mean is: 511.452
# CPU Standard Deviation: 283.74, Time taken: 16ms
# =======================================
# GPU Min is: 2
# CPU Min is: 2
# =======================================
# GPU Max is: 996
# CPU Max is: 996
# =======================================
